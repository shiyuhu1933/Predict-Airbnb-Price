# %% [markdown]
# <a href="https://colab.research.google.com/github/shiyuhu1933/Predict-Airbnb-Price/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
from spacy.matcher import Matcher

# %%
with open("/content/drive/MyDrive/TextExtraction/result.txt", "r") as f:
    text = str(f.read())

# %%
nlp = spacy.load("en_core_web_sm")
matcher = Matcher(nlp.vocab)
pattern = [{"POS": "PROPN"}]
matcher.add("PROPER_NOUNS", [pattern])
doc = nlp(text)
matches = matcher(doc)

# %%
print (matches)
# Out:
# [(3232560085755078826, 2, 3), (3232560085755078826, 3, 4), (3232560085755078826, 7, 8), (3232560085755078826, 8, 9), (3232560085755078826, 9, 10), (3232560085755078826, 13, 14), (3232560085755078826, 14, 15), (3232560085755078826, 17, 18), (3232560085755078826, 19, 20), (3232560085755078826, 20, 21), (3232560085755078826, 24, 25), (3232560085755078826, 27, 28), (3232560085755078826, 30, 31), (3232560085755078826, 34, 35), (3232560085755078826, 35, 36), (3232560085755078826, 36, 37), (3232560085755078826, 37, 38), (3232560085755078826, 39, 40), (3232560085755078826, 42, 43), (3232560085755078826, 43, 44), (3232560085755078826, 45, 46), (3232560085755078826, 46, 47), (3232560085755078826, 47, 48), (3232560085755078826, 50, 51), (3232560085755078826, 56, 57), (3232560085755078826, 58, 59), (3232560085755078826, 60, 61), (3232560085755078826, 62, 63), (3232560085755078826, 65, 66), (3232560085755078826, 66, 67), (3232560085755078826, 69, 70), (3232560085755078826, 71, 72), (3232560085755
# ...

# %%
for match in matches[:10]:
  print(match, doc[match[1]:match[2]])
# Out:
# (3232560085755078826, 2, 3) KINGS
# (3232560085755078826, 3, 4) COUNTY
# (3232560085755078826, 7, 8) PM
# (3232560085755078826, 8, 9) INDEX
# (3232560085755078826, 9, 10) NO
# (3232560085755078826, 13, 14) NYSCEF
# (3232560085755078826, 14, 15) DOC
# (3232560085755078826, 17, 18) .
# (3232560085755078826, 19, 20) RECEIVED
# (3232560085755078826, 20, 21) NYSCEF

# %%
nlp = spacy.load("en_core_web_sm")

# %%
#Get the BLOCK_INFO
matcher = Matcher(nlp.vocab)
pattern = [{"LOWER": "block", "OP": "+"},
           {"POS" : "PUNCT", "OP" : "?"},
           {"POS" : "SPACE", "OP" : "?"},
           {"POS" : "NUM", "OP" : "+"}]
matcher.add("PROPER_NOUNS", [pattern])
doc = nlp(str(text))
matches = matcher(doc)
print (len(matches))

Block_list = []
Block_string = ""
df1 = pd.DataFrame(lst, columns=cols)
for match in matches:
  print(str((doc[match[1]:match[2]])))
  block_string = str((doc[match[1]:match[2]]))
  Block_list += [block_string]

print(Block_list)
df = DataFrame(Block_list, columns=['BLOCK_INFO'])
df.head(len(df))
# Out:
# 19
# Block 4415
# Block 4112
# Block 3921
# Block 8054
# Block 3228
# Block 3403
# Block: 6579
# BLOCK 1468
# Block 3554
# Block: 1615
# Block
# 5146
# Block 2072
# Block: 4001
# Block 3999
# Block 803
# Block: 8238
# Block: 4754
# Block 8166
# Block 8017
# ['Block 4415', 'Block 4112', 'Block 3921', 'Block 8054', 'Block 3228', 'Block 3403', 'Block: 6579', 'BLOCK 1468', 'Block 3554', 'Block: 1615', 'Block\n5146', 'Block 2072', 'Block: 4001', 'Block 3999', 'Block 803', 'Block: 8238', 'Block: 4754', 'Block 8166', 'Block 8017']
#      BLOCK_INFO
# 0    Block 4415
# 1    Block 4112
# 2    Block 3921
# 3    Block 8054
# 4    Block 3228
# 5    Block 3403
# 6   Block: 6579
# 7    BLOCK 1468
# 8    Block 3554
# 9   Block: 1615
# 10  Block\n5146
# 11   Block 2072
# 12  Block: 4001
# 13   Block 3999
# 14    Block 803
# 15  Block: 8238
# 16  Block: 4754
# 17   Block 8166
# 18   Block 8017

# %%
#Get the LOT_INFO
matcher = Matcher(nlp.vocab)
pattern_Lot = [{"LOWER": "lot", "OP": "+"},
           {"POS" : "PUNCT", "OP" : "?"},
           {"POS" : "SPACE", "OP" : "?"},
           {"POS" : "NUM", "OP" : "+"}]
matcher.add("PROPER_NOUNS", [pattern_Lot])
doc = nlp(str(text))
matches = matcher(doc)
print (len(matches))

lot_list = []
lot_string = ""
df2 = pd.DataFrame(lst, columns=cols)
for match in matches:
  print(str((doc[match[1]:match[2]])))
  lot_string = str((doc[match[1]:match[2]]))
  lot_list += [lot_string]

print(lot_list)
df2 = DataFrame(lot_list, columns=['Lot_INFO'])
df2.head(len(df))
# Out:
# 19
# Lot 1463
# Lot 92
# Lot 2
# Lot 51
# Lot 30
# Lot 16
# Lot: 54
# LOT 31
# Lot 38
# Lot: 24
# Lot 26‘on
# Lot 27
# Lot: 27
# Lot 9
# Lot 9
# Lot: 35
# Lot: 4
# Lot 38
# Lot 73
# ['Lot 1463', 'Lot 92', 'Lot 2', 'Lot 51', 'Lot 30', 'Lot 16', 'Lot: 54', 'LOT 31', 'Lot 38', 'Lot: 24', 'Lot 26‘on', 'Lot 27', 'Lot: 27', 'Lot 9', 'Lot 9', 'Lot: 35', 'Lot: 4', 'Lot 38', 'Lot 73']
#      Lot_INFO
# 0    Lot 1463
# 1      Lot 92
# 2       Lot 2
# 3      Lot 51
# 4      Lot 30
# 5      Lot 16
# 6     Lot: 54
# 7      LOT 31
# 8      Lot 38
# 9     Lot: 24
# 10  Lot 26‘on
# 11     Lot 27
# 12    Lot: 27
# 13      Lot 9
# 14      Lot 9
# 15    Lot: 35
# 16     Lot: 4
# 17     Lot 38
# 18     Lot 73

# %%
import pandas as pd

df= pd.DataFrame()
df['list1'] = Block_list
df['list2'] = lot_list
print(df)
# Out:
#           list1      list2
# 0    Block 4415   Lot 1463
# 1    Block 4112     Lot 92
# 2    Block 3921      Lot 2
# 3    Block 8054     Lot 51
# 4    Block 3228     Lot 30
# 5    Block 3403     Lot 16
# 6   Block: 6579    Lot: 54
# 7    BLOCK 1468     LOT 31
# 8    Block 3554     Lot 38
# 9   Block: 1615    Lot: 24
# 10  Block\n5146  Lot 26‘on
# 11   Block 2072     Lot 27
# 12  Block: 4001    Lot: 27
# 13   Block 3999      Lot 9
# 14    Block 803      Lot 9
# 15  Block: 8238    Lot: 35
# 16  Block: 4754     Lot: 4
# 17   Block 8166     Lot 38
# 18   Block 8017     Lot 73
